# %% [markdown]
# # Installs demo prerequisites

# %%
# !pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# !./ngrok authtoken 22xukLCRRZODxef1lLiW9vtVLeY_frZp5ZT2tVgCNrzpAs5N
# Out:
# --2022-06-02 09:15:29--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 18.205.222.128, 52.202.168.65, 54.161.241.46, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.205.222.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  76.9MB/s    in 0.2s
#
# 2022-06-02 09:15:29 (76.9 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %% [markdown]
# # Download dataset and github repository

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b.tar.gz
# Out:
# --2022-06-02 09:15:37--  https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2753340328 (2.6G) [application/x-gzip]
# Saving to: ‘fgvc-aircraft-2013b.tar.gz’
#
# fgvc-aircraft-2013b 100%[===================>]   2.56G  36.4MB/s    in 75s
#
# 2022-06-02 09:16:52 (35.2 MB/s) - ‘fgvc-aircraft-2013b.tar.gz’ saved [2753340328/2753340328]

# %%
# !git clone https://github.com/anavuongdin/FGVC-Aircraft-Inception-v4.git
# !tar -xf /content/fgvc-aircraft-2013b.tar.gz --directory /content/FGVC-Aircraft-Inception-v4/data
# %cd /content/FGVC-Aircraft-Inception-v4
# Out:
# Cloning into 'FGVC-Aircraft-Inception-v4'...
# remote: Enumerating objects: 282, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (221/221), done.
# remote: Total 282 (delta 84), reused 249 (delta 54), pack-reused 0
# Receiving objects: 100% (282/282), 2.83 MiB | 26.58 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/FGVC-Aircraft-Inception-v4

# %% [markdown]
# # Running a streamlit server

# %%
# %cd /content
get_ipython().system_raw('./ngrok http 8501 &')
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    'import sys, json; print("Execute the next cell and the go to the following URL: " +json.load(sys.stdin)["tunnels"][0]["public_url"])'
# !streamlit run /content/FGVC-Aircraft-Inception-v4/fgvc-st.py
# Out:
# /content
# Your account is limited to 1 simultaneous ngrok agent session.
# Active ngrok agent sessions in region 'us':
#   - ts_2A0zsXThTbrKkh7PV3FmlroirGc (34.86.60.218)
#
# ERR_NGROK_108
#
# Execute the next cell and the go to the following URL: https://05ca-34-86-60-218.ngrok.io
# 2022-06-02 09:18:44.200 INFO    numexpr.utils: NumExpr defaulting to 2 threads.
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://34.86.60.218:8501
#
# new_layers 1
# new_layers 1
# new_layers 1
# new_layers 1
# new_layers 1
# new_layers 1
# new_layers 1
# new_layers 1
# new_layers 1
# new_layers 1
#   Stopping...
#   Stopping...

# %% [markdown]
# # Train model, skip if you don't wish to

# %%
# !python train.py --dataset "aircraft" --data_dir "./data/" --num-classes 105 --model "inception_v4" --pretrained --new-layers=1 -b 32 --epochs 1 --lr 0.01 0.02 0.03 --num-lowlrs=8 --weight-decay 0.0005 --decay-epochs 10 --decay-rate 0.9 --mixup 0.2 --L2SP --L2SP_rates 0.1 --aa rand-m9-mstd0.5-inc1 --reprob 0.5 --remode pixel --output "./experiments/..." -j 16 --amp --native-amp
# Out:
# Training with a single process on 1 GPUs.
# using Torch native amp
# Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-cadene/inceptionv4-8e4777a0.pth)
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-cadene/inceptionv4-8e4777a0.pth" to /root/.cache/torch/hub/checkpoints/inceptionv4-8e4777a0.pth
# new_layers 1
# Model inception_v4 created, param count:41304201
# Use FGVC mean&std
# Data processing configuration for current model + dataset:
# 	input_size: (3, 299, 299)
# 	interpolation: bicubic
# 	mean: (0.48933587508932375, 0.5183537408957618, 0.5387914411673883)
# 	std: (0.22388883112804625, 0.21641635409388751, 0.24615605842636115)
# 	crop_pct: 0.875
# last_linear.bias
# last_linear.weight
# features.21.branch3.1.bn.bias
# features.21.branch3.1.bn.weight
# features.21.branch3.1.conv.weight
# features.21.branch2_3b.bn.bias
# features.21.branch2_3b.bn.weight
# ...
